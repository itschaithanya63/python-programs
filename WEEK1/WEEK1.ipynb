# %%
print("Chaithanya")
# Out:
# Chaithanya

# %%
print("Hello Wolrd")
# Out:
# Hello Wolrd

# %%
name=input("Enter your name")
print("Hi..My name is",name)
# Out:
# Enter your name Chaithanya
# Hi..My name is Chaithanya

# %%
uniname=input("Enter your university")
print("University name:",uniname)
# Out:
# Enter your university Garden City University
# University name: Garden City University

# %%
a=10
b=20
sum=a+b
print(sum)
# Out:
# 30

# %%
x=int(input("Enter num1"))
y=int(input("Enter num2"))
add=x+y
print(add)
# Out:
# Enter num1 5
# Enter num2 10
# 15

# %%
num=int(input("Enter the number"))
if num%2==0 :
    print(num ,"is even")
else:
    print(num,"is odd")
# Out:
# Enter the number 24
# 24 is even

# %%
p=float(input(" Enter Principal amount"))
r=float(input("Enter interest rate"))
t=float(input("Enter time in yeras"))
SI=(p*r*t)/100
print("Simple interest is",SI)
# Out:
#  Enter Principal amount 5000
# Enter interest rate 5
# Enter time in yeras 2
# Simple interest is 500.0

# %%
a=5
b=10
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 15
# -5
# 50
# 0.5

# %%
a=10
b=6
print(a/b)
print(a//b)
# Out:
# 1.6666666666666667
# 1

# %%
a=int(input("Enter a"))
b=int(input("Enter b"))
print(a+b)
# Out:
# Enter a 5
# Enter b 9
# 14

# %%
a=int(input())
b=int(input())
print("Before swapping a=",a)
print("Before swapping b=",b)
temp=a
a=b
b=temp
print("After swapping a=",a)
print("After swapping b=",b)
# Out:
#  5
#  6
# Before swapping a= 5
# Before swapping b= 6
# After swapping a= 6
# After swapping b= 5

# %%
n1=float(input())
n2=float(input())
n3=float(input())
avg=(n1+n2+n3)/3
print("Average of",n1,n2,n3,"is",avg)
# Out:
#  5
#  6
#  8
# Average of 5.0 6.0 8.0 is 6.333333333333333

# %%
num=float(input("Enter a number"))
sq=num*num
print("Square of",num,"is",sq)
# Out:
# Enter a number 5
# Square of 5.0 is 25.0

# %%
celsius = float(input("Enter temperature in Celsius"))

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit is", fahrenheit)
# Out:
# Enter temperature in Celsius 5
# Temperature in Fahrenheit is 41.0

# %%
num1=float(input("first operand"))
num2=float(input("second operand"))
a=num1+num2
b=num1-num2
c=num1*num2
d=num1/num2
print("Addition",a)
print("Subtraction",b)
print("Multiplication",c)
print("Division",d)
# Out:
# first operand 5
# second operand 9
# Addition 14.0
# Subtraction -4.0
# Multiplication 45.0
# Division 0.5555555555555556

# %%
num=int(input("Enter a number"))
if num>0:
    print("Positive")
elif num<0:
    print("Negative")
else :
    print("Zero")
# Out:
# Enter a number -8
# Negative
